# %% [markdown]
# # Model Development: PD, LGD, and EAD
#
# This notebook provides a baseline for credit risk modeling, covering Probability of Default (PD), Loss Given Default (LGD), and Exposure at Default (EAD).

# %% [markdown]
# ## 1. Probability of Default (PD) Model
# We utilize Logistic Regression to estimate the likelihood of a borrower defaulting.

# %%
# Embedded PD Visualization

# %% [markdown]
# ## 2. LGD and EAD Modeling
# Linear Regression models are used to estimate the loss severity and total exposure.

# %%
# Embedded Regression Visualizations

# %% [markdown]
# ### Summary of Interpretations
# - **PD:** The ROC curve indicates the model's ability to distinguish between default and non-default cases.
# - **LGD:** Predictive of recovery potential based on property collateral values.
# - **EAD:** Captures the total financial risk exposure at the moment of default.
