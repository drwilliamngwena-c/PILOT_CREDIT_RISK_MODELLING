# %% [markdown]
# # 7. Model Evaluation: Visual Report
# Detailed performance analysis for PD, LGD, and EAD with embedded results.

# %% [markdown]
# ## 1. Probability of Default (PD) Performance

# %%
# PD Metrics

# %% [markdown]
# ## 2. LGD and EAD Regression Performance

# %%
# Regression Metrics
