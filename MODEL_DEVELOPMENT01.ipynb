# %% [markdown]
# # 6. Model Development (PD, LGD, EAD)
#
# This notebook contains the baseline training and initial results.

# %%
from sklearn.linear_model import LogisticRegression, LinearRegression

# Re-train models
pd_model = LogisticRegression(max_iter=5000, random_state=42)
pd_model.fit(X_train, y_train)

lgd_model = LinearRegression()
lgd_model.fit(X_train_lgd, y_train_lgd)

ead_model = LinearRegression()
ead_model.fit(X_train_ead, y_train_ead)

print("Models successfully re-trained in exported notebook.")
