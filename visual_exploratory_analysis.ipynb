# %% [markdown]
# # Exploratory Data Analysis Report
#
# Visualizing key risk drivers for PD, LGD, and EAD.

# %% [markdown]
# ## 1. Probability of Default (PD) by Region

# %%
# Code to generate PD graph
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x='Region', y='Status', data=df, estimator=lambda x: sum(x)/len(x)*100)

# %% [markdown]
# ## 2. Loss Given Default (LGD) Factors

# %%
# Code to generate LGD graph
sns.scatterplot(x='property_value', y='loan_amount', data=df[df['Status']==1])
